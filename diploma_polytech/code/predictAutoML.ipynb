# %% [markdown]
# https://colab.research.google.com/drive/1uMKT1vX88BZo21Ph0Gc-cDNpm7SkiK1G?authuser=0#scrollTo=LDZI4EpWGRz6

# %%
import pandas as pd
import numpy as np
#from lightautoml.automl.presets.tabular_presets import TabularAutoML, TabularUtilizedAutoML
from lightautoml.tasks import Task
# from lightautoml.dataset import NumpyDataset
# from lightautoml.reader import NumpyReader
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from lightautoml.automl.presets.tabular_presets import TabularAutoML
# from lightautoml.tasks import Task
from lightautoml.report.report_deco import ReportDeco
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 4
#       2 import numpy as np
#       3 #from lightautoml.automl.presets.tabular_presets import TabularAutoML, TabularUtilizedAutoML
# ----> 4 from lightautoml.tasks import Task
#       5 # from lightautoml.dataset import NumpyDataset
#       6 # from lightautoml.reader import NumpyReader
#       7 from sklearn.metrics import roc_auc_score, roc_curve
#
# File d:\My_ML\.venv\Lib\site-packages\lightautoml\tasks\__init__.py:3
#       1 """Define the task to solve its loss, metric."""
# ----> 3 from .base import Task
#       6 __all__ = ["losses", "base", "common_metric", "utils", "Task"]
#
# File d:\My_ML\.venv\Lib\site-packages\lightautoml\tasks\base.py:16
#      12 from typing import Union
#      14 import numpy as np
# ---> 16 from .common_metric import _valid_metric_args
#      17 from .common_metric import _valid_str_metric_names
#      18 from .losses import CBLoss
#
# File d:\My_ML\.venv\Lib\site-packages\lightautoml\tasks\common_metric.py:9
#       5 from typing import Optional
#       7 import numpy as np
# ----> 9 from sklearn.metrics import accuracy_score
#      10 from sklearn.metrics import f1_score
#      11 from sklearn.metrics import log_loss
#
# File d:\My_ML\.venv\Lib\site-packages\sklearn\__init__.py:84
#      70     # We are not importing the rest of scikit-learn during the build
#      71     # process, as it may not be compiled yet
#      72 else:
#    (...)
#      78     # later is linked to the OpenMP runtime to make it possible to introspect
#      79     # it and importing it first would fail if the OpenMP dll cannot be found.
#      80     from . import (
#      81         __check_build,  # noqa: F401
#      82         _distributor_init,  # noqa: F401
#      83     )
# ---> 84     from .base import clone
#      85     from .utils._show_versions import show_versions
#      87     __all__ = [
#      88         "calibration",
#      89         "cluster",
#    (...)
#     130         "show_versions",
#     131     ]
#
# File d:\My_ML\.venv\Lib\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File d:\My_ML\.venv\Lib\site-packages\sklearn\utils\__init__.py:11
#       9 from . import _joblib, metadata_routing
#      10 from ._bunch import Bunch
# ---> 11 from ._chunking import gen_batches, gen_even_slices
#      12 from ._estimator_html_repr import estimator_html_repr
#      14 # Make _safe_indexing importable from here for backward compat as this particular
#      15 # helper is considered semi-private and typically very useful for third-party
#      16 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      17 # _safe_indexing was included in our public API documentation despite the leading
#      18 # `_` in its name.
#
# File d:\My_ML\.venv\Lib\site-packages\sklearn\utils\_chunking.py:8
#       5 import numpy as np
#       7 from .._config import get_config
# ----> 8 from ._param_validation import Interval, validate_params
#      11 def chunk_generator(gen, chunksize):
#      12     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      13     chunk may have a length less than ``chunksize``."""
#
# File d:\My_ML\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:11
#       8 from numbers import Integral, Real
#      10 import numpy as np
# ---> 11 from scipy.sparse import csr_matrix, issparse
#      13 from .._config import config_context, get_config
#      14 from .validation import _is_arraylike_not_scalar
#
# File d:\My_ML\.venv\Lib\site-packages\scipy\sparse\__init__.py:294
#     288 # Original code by Travis Oliphant.
#     289 # Modified and extended by Ed Schofield, Robert Cimrman,
#     290 # Nathan Bell, and Jake Vanderplas.
#     292 import warnings as _warnings
# --> 294 from ._base import *
#     295 from ._csr import *
#     296 from ._csc import *
#
# File d:\My_ML\.venv\Lib\site-packages\scipy\sparse\_base.py:5
#       2 from warnings import warn
#       4 import numpy as np
# ----> 5 from scipy._lib._util import VisibleDeprecationWarning
#       7 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       8                        get_sum_dtype, isdense, isscalarlike,
#       9                        matrix, validateaxis,)
#      11 from ._matrix import spmatrix
#
# File d:\My_ML\.venv\Lib\site-packages\scipy\_lib\_util.py:18
#      10 from typing import (
#      11     Optional,
#      12     Union,
#      13     TYPE_CHECKING,
#      14     TypeVar,
#      15 )
#      17 import numpy as np
# ---> 18 from scipy._lib._array_api import array_namespace
#      21 AxisError: type[Exception]
#      22 ComplexWarning: type[Warning]
#
# File d:\My_ML\.venv\Lib\site-packages\scipy\_lib\_array_api.py:17
#      14 import numpy as np
#      16 from scipy._lib import array_api_compat
# ---> 17 from scipy._lib.array_api_compat import (
#      18     is_array_api_obj,
#      19     size,
#      20     numpy as np_compat,
#      21 )
#      23 __all__ = ['array_namespace', '_asarray', 'size']
#      26 # To enable array API and strict array-like input validation
#
# File d:\My_ML\.venv\Lib\site-packages\scipy\_lib\array_api_compat\numpy\__init__.py:1
# ----> 1 from numpy import *
#       3 # from numpy import * doesn't overwrite these builtin names
#       4 from numpy import abs, max, min, round
#
# File d:\My_ML\.venv\Lib\site-packages\numpy\__init__.py:378, in __getattr__(attr)
#     376 try:
#     377     x = ones(2, dtype=float32)
# --> 378     if not abs(x.dot(x) - float32(2.0)) < 1e-5:
#     379         raise AssertionError()
#     380 except AssertionError:
#
# ModuleNotFoundError: No module named 'numpy.rec'

# %%
data = pd.read_csv('D:/my_ML/diploma_polytech/data/raw/vehicle_ins_data_1.csv', sep = ";",index_col= False)

# %%
TARGET_NAME = 'Cost_claims_year'
task = Task('Regression')
automl = TabularAutoML(
    task=task,
    timeout=3600,  # Максимальное время работы модели (секунды)
    cpu_limit=4,   # Количество CPU
    memory_limit=16  # Ограничение памяти (ГБ)
)
# Обертка для генерации отчетов
# automl = ReportDeco(automl)
automl_with_report = ReportDeco(output_path='report.html')(automl)
# Определяем роли переменных
roles = {'target': TARGET_NAME}

# %%
of_preds = automl_with_report.fit_predict(
    train_data=data,
    
    roles=roles,
    verbose=1,
    #report=True  # Активация автоматического отчета
)
# Генерация отчета
# tabular_report = tabularReport(automl)
# tabular_report.generate()
