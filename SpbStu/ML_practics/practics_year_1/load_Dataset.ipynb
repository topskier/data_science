# %%
# %env CLEARML_WEB_HOST=https://app.clear.ml/
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# Python 3.12
# %env CLEARML_API_ACCESS_KEY=17EH8MKOUXFTCCY4ZNGB7KOEIGXU59
# %env CLEARML_API_SECRET_KEY=I3XdWFGE-rw1-16wvP-F1uV6Uq143N7igmA6hAOetL8a8oj-4Xi32kYHC78lhjSCRzc
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml/
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=17EH8MKOUXFTCCY4ZNGB7KOEIGXU59
# env: CLEARML_API_SECRET_KEY=I3XdWFGE-rw1-16wvP-F1uV6Uq143N7igmA6hAOetL8a8oj-4Xi32kYHC78lhjSCRzc

# %%
import pandas as pd
import optbinning as ob
import sklearn as sl
from optbinning import OptimalBinning, BinningProcess
import matplotlib.pyplot as plt
#import seaborn as sns
import numpy as np
import ydata_profiling
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.linear_model import Lasso
from sklearn import metrics
from sklearn import linear_model
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from ydata_profiling import ProfileReport
import category_encoders as ce
from clearml import Task, Logger, StorageManager, Dataset

# %%
trainingSample = pd.read_csv('D:/maga_1/ML/data/external/teaching_sample.csv', index_col= False)
testingSample = pd.read_csv('D:/maga_1/ML/data/external/testing_sample.csv', index_col= False)
dataset_training = Dataset.create(
    dataset_project="MLOps project", dataset_name="Training_dataset"
)
dataset_testing = Dataset.create(
    dataset_project="MLOps project", dataset_name="Testing_dataset"
)
# Out:
# ClearML results page: https://app.clear.ml/projects/f25a9b2f44fc4222badbd57dec4b9a33/experiments/bb247b429ecf444ca29073aa42112d46/output/log
# ClearML dataset page: https://app.clear.ml/datasets/simple/f25a9b2f44fc4222badbd57dec4b9a33/experiments/bb247b429ecf444ca29073aa42112d46
# ClearML results page: https://app.clear.ml/projects/9cd23c28e40d4f73978ec55c1bb96b5a/experiments/6d5f1fcdd3a0482dac724b45e9e17300/output/log
# ClearML dataset page: https://app.clear.ml/datasets/simple/9cd23c28e40d4f73978ec55c1bb96b5a/experiments/6d5f1fcdd3a0482dac724b45e9e17300

# %%
dataset_training.add_files(path=r"D:/maga_1/ML/data/external/teaching_sample.csv")
dataset_training.upload()
dataset_testing.add_files(path=r"D:/maga_1/ML/data/external/testing_sample.csv")
dataset_testing.upload()
# Out:
# Uploading dataset changes (1 files compressed to 1.21 MiB) to https://files.clear.ml
# File compression and upload completed: total size 1.21 MiB, 1 chunk(s) stored (average size 1.21 MiB)
# Uploading dataset changes (1 files compressed to 1.26 MiB) to https://files.clear.ml
# File compression and upload completed: total size 1.26 MiB, 1 chunk(s) stored (average size 1.26 MiB)

# %%
dataset_training.finalize()
dataset_testing.finalize()
# Out:
# True
